# %%
x=10
print(x)
# Out:
# 10

# %%
a=5
print(-a)
# Out:
# -5

# %%
p=10
q=5
print(p>q)
# Out:
# True

# %%
x=2
y=5
print(x&y)
# Out:
# 0

# %%
a=5
b=3
print(a&b)
# Out:
# 1

# %%
x=10
y=10
print(x != y)
# Out:
# False
