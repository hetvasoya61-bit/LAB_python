# %%
x="hello"
print (x)
# Out:
# hello

# %%
x=210
print(x)
# Out:
# 210

# %%
x=20.5
print (x)
# Out:
# 20.5

# %%
x= ["apple","banana","cherry"]
print(x)
# Out:
# ['apple', 'banana', 'cherry']

# %%
x= ("apple","banana","cherry")
print(x)
# Out:
# ('apple', 'banana', 'cherry')

# %%
x=20
y=11
print(x<y)
# Out:
# False

# %%
a=1
print(a)
# Out:
# 1

# %%
x=True
y=False
print(x<y)
# Out:
# False
